# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### importing modules and dataset

# %%
df=pd.read_csv("mobile.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df["price_range"][447]
# Out:
# 2

# %%
df["fc"].value_counts()
# Out:
# 0     474
# 1     245
# 2     189
# 3     170
# 5     139
# 4     133
# 6     112
# 7     100
# 9      78
# 8      77
# 10     62
# 11     51
# 12     45
# 13     40
# 16     24
# 15     23
# 14     20
# 18     11
# 17      6
# 19      1
# Name: fc, dtype: int64

# %% [markdown]
# ### finding shape of our dataset

# %%
df.shape
# Out:
# (2000, 21)

# %%
print('number of rows=',df.shape[0])
print('number of col=',df.shape[1])
# Out:
# number of rows= 2000
# number of col= 21

# %% [markdown]
# ### Get information about our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Check Null values in the Dataset

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df=df.drop(['talk_time','sc_h','sc_w','clock_speed','blue','n_cores','wifi','three_g','four_g','px_height','px_width','m_dep','touch_screen','mobile_wt'],axis=1)
df.head()
# Out:
#    battery_power  dual_sim  fc  int_memory  pc   ram  price_range
# 0            842         0   1           7   2  2549            1
# 1           1021         1   0          53   6  2631            2
# 2            563         1   2          41   6  2603            2
# 3            615         0   0          10   9  2769            2
# 4           1821         0  13          44  14  1411            1

# %%
df.tail()
# Out:
#       battery_power  dual_sim  fc  int_memory  pc   ram  price_range
# 1995            794         1   0           2  14   668            0
# 1996           1965         1   0          39   3  2032            2
# 1997           1911         1   1          36   3  3057            3
# 1998           1512         0   4          46   5   869            0
# 1999            510         1   5          45  16  3919            3

# %%
x= df.drop('price_range',axis=1)#independent variables
x
# Out:
#       battery_power  dual_sim  fc  int_memory  pc   ram
# 0               842         0   1           7   2  2549
# 1              1021         1   0          53   6  2631
# 2               563         1   2          41   6  2603
# 3               615         0   0          10   9  2769
# 4              1821         0  13          44  14  1411
# ...             ...       ...  ..         ...  ..   ...
# 1995            794         1   0           2  14   668
# 1996           1965         1   0          39   3  2032
# 1997           1911         1   1          36   3  3057
# 1998           1512         0   4          46   5   869
# 1999            510         1   5          45  16  3919
#
# [2000 rows x 6 columns]

# %%
y=df['price_range']
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %% [markdown]
# ### Not handling imbalanced

# %%
#exited is the target variable and here we check distribution of it
df['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
#visualization
import seaborn as sns

# %%
sns.countplot(x=df['price_range'])
#from the graph we can say that our data set is imbanlanced
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %% [markdown]
# ### Splitting dataset into train and test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=48)
#testing set 20% data
#random_state has the n.o of samples
#stratify=dependent variable(it forces same class balance on train and test data as original data)
#as we have imbalanced data if we randomly assign 20% data then there is a chance of risk
# ending up with no cases of minorityclasses in test set so we use stratify parameter

# %%
x_train
# Out:
#       battery_power  dual_sim  fc  int_memory  pc   ram
# 447            1349         1  15          62  16  2756
# 1254           1083         0   6          52  20   681
# 1492           1130         1   1          29  14   432
# 1399            672         0   7          35  17  1403
# 70             1448         1   6          45  11  3378
# ...             ...       ...  ..         ...  ..   ...
# 347             667         0   6           3  13  2855
# 1476           1638         0   6           2  11  2299
# 1361           1549         1   0          27   7   436
# 563            1290         0   0           3   4  1214
# 1536           1412         0   9          57  10  1853
#
# [1400 rows x 6 columns]

# %%
jk=x_train.values.tolist()
jk
# Out:
# [[1349, 1, 15, 62, 16, 2756],
#  [1083, 0, 6, 52, 20, 681],
#  [1130, 1, 1, 29, 14, 432],
#  [672, 0, 7, 35, 17, 1403],
#  [1448, 1, 6, 45, 11, 3378],
#  [555, 1, 5, 38, 10, 1686],
#  [844, 1, 1, 22, 2, 3154],
#  [1062, 0, 3, 45, 4, 911],
#  [1589, 0, 0, 5, 2, 3430],
#  [1317, 1, 2, 43, 3, 3436],
#  [532, 1, 3, 8, 10, 728],
#  [1977, 1, 7, 54, 18, 1971],
#  [1059, 1, 0, 50, 1, 619],
#  [1623, 0, 6, 61, 12, 1510],
#  [1272, 1, 0, 22, 8, 2235],
#  [1128, 0, 9, 46, 10, 1434],
#  [1944, 0, 1, 26, 9, 2322],
#  [627, 0, 2, 20, 8, 896],
#  [1792, 0, 3, 62, 8, 2563],
#  [618, 0, 9, 13, 15, 1424],
#  [1379, 1, 14, 63, 17, 651],
#  [1558, 0, 0, 27, 1, 3598],
#  [834, 0, 2, 27, 16, 1591],
#  [1741, 0, 1, 55, 3, 2575],
#  [1786, 0, 11, 61, 14, 3033],
#  [1602, 0, 4, 46, 5, 1862],
#  [1431, 0, 0, 56, 1, 461],
#  [1285, 1, 4, 11, 7, 3966],
#  [1310, 0, 0, 33, 14, 1301],
#  [858, 0, 1, 50, 2, 3978],
#  [1063, 0, 0, 26, 2, 3809],
#  [908, 0, 1, 44, 2, 3518],
#  [576, 0, 1, 30, 5, 2800],
#  [1058, 0, 2, 19, 14, 418],
#  [1345, 0, 7, 38, 11, 1322],
#  [1871, 0, 7, 20, 14, 2144],
#  [1776, 0, 2, 20, 16, 2671],
#  [538, 1, 0, 25, 7, 2215],
#  [958, 0, 9, 60, 12, 1417],
#  [1816, 1, 0, 50, 2, 3637],
#  [1018, 1, 7, 63, 18, 3048],
#  [793, 1, 5, 30, 15, 2332],
#  [768, 0, 16, 56, 20, 952],
#  [1270, 0, 0, 58, 1, 3299],
#  [1922, 0, 15, 42, 16, 3564],
#  [1430, 0, 3, 56, 5, 752],
#  [1263, 0, 0, 5, 3, 1958],
#  [1009, 1, 2, 2, 14, 1716],
#  [868, 0, 0, 30, 0, 1653],
#  [1689, 0, 17, 24, 18, 2766],
#  [1007, 0, 0, 45, 2, 3648],
#  [864, 1, 0, 53, 1, 493],
#  [1611, 1, 11, 3, 14, 1595],
#  [912, 0, 3, 47, 6, 1321],
#  [1494, 0, 2, 47, 9, 3202],
#  [912, 0, 1, 54, 5, 2330],
#  [1197, 1, 9, 20, 10, 2885],
#  [1565, 0, 0, 38, 1, 308],
#  [704, 0, 8, 29, 10, 1122],
#  [1225, 1, 8, 13, 12, 3836],
#  [1524, 1, 5, 57, 12, 947],
#  [983, 1, 0, 45, 11, 2052],
#  [1579, 0, 0, 27, 18, 1713],
#  [841, 1, 8, 39, 13, 2942],
#  [1986, 1, 7, 39, 19, 3476],
#  [1617, 1, 3, 30, 4, 829],
#  [1265, 0, 7, 49, 16, 1362],
#  [1974, 1, 9, 10, 12, 1433],
#  [527, 1, 4, 53, 11, 1302],
#  [1749, 1, 7, 49, 8, 2195],
#  [1578, 0, 8, 3, 20, 3483],
#  [1310, 1, 3, 15, 11, 2518],
#  [598, 1, 7, 21, 10, 3293],
#  [504, 1, 2, 54, 10, 2378],
#  [587, 0, 16, 51, 17, 2746],
#  [1514, 0, 0, 27, 1, 1152],
#  [1237, 0, 2, 27, 5, 2454],
#  [1128, 0, 12, 53, 14, 2982],
#  [686, 0, 11, 3, 15, 570],
#  [950, 0, 9, 55, 10, 1095],
#  [1778, 0, 0, 23, 11, 3941],
#  [1234, 1, 1, 33, 3, 1449],
#  [1407, 1, 5, 16, 6, 1068],
#  [1449, 1, 0, 52, 0, 2036],
#  [1347, 1, 10, 56, 19, 2456],
#  [649, 0, 4, 19, 12, 739],
#  [1195, 1, 2, 8, 6, 643],
#  [1250, 0, 14, 20, 18, 3314],
#  [603, 0, 8, 12, 20, 1543],
#  [1375, 0, 3, 9, 19, 3869],
#  [1442, 1, 1, 27, 8, 991],
#  [1517, 0, 2, 8, 18, 2738],
#  [633, 0, 0, 46, 10, 1401],
#  [1197, 0, 3, 20, 7, 1797],
#  [880, 1, 1, 44, 15, 3132],
#  [1097, 1, 6, 64, 8, 1725],
#  [1476, 1, 0, 55, 5, 1529],
#  [1417, 0, 10, 45, 19, 2129],
#  [1263, 1, 1, 32, 2, 3372],
#  [623, 0, 2, 6, 4, 3657],
#  [673, 0, 13, 35, 14, 3541],
#  [1394, 1, 10, 62, 13, 473],
#  [1656, 1, 8, 38, 17, 1499],
#  [1392, 0, 0, 44, 2, 1280],
#  [1207, 0, 0, 58, 0, 503],
#  [1066, 0, 2, 7, 18, 468],
#  [1175, 0, 10, 25, 12, 3153],
#  [783, 1, 9, 27, 11, 1185],
#  [1569, 1, 4, 54, 6, 3905],
#  [625, 0, 12, 33, 20, 3801],
#  [1181, 0, 12, 61, 16, 2020],
#  [1404, 0, 16, 44, 20, 1196],
#  [1809, 0, 3, 59, 4, 2324],
#  [1021, 0, 7, 9, 12, 1355],
#  [809, 0, 10, 21, 19, 1274],
#  [1249, 0, 3, 55, 8, 531],
#  [1994, 1, 2, 7, 7, 3622],
#  [1657, 0, 3, 42, 16, 2597],
#  [831, 1, 7, 26, 11, 1704],
#  [1489, 1, 8, 32, 16, 776],
#  [1049, 1, 8, 2, 10, 433],
#  [1972, 0, 9, 14, 18, 1316],
#  [1893, 1, 8, 63, 11, 3822],
#  [1902, 0, 10, 13, 11, 940],
#  [1462, 1, 1, 25, 18, 824],
#  [623, 1, 0, 15, 1, 3510],
#  [987, 1, 1, 20, 3, 1454],
#  [832, 1, 2, 39, 3, 1799],
#  [1944, 1, 0, 31, 10, 2560],
#  [1958, 0, 6, 52, 14, 3064],
#  [805, 0, 1, 34, 2, 3647],
#  [783, 1, 0, 43, 4, 2016],
#  [1742, 1, 5, 43, 7, 1921],
#  [1993, 0, 10, 27, 11, 2437],
#  [919, 1, 11, 13, 15, 1028],
#  [1020, 1, 3, 27, 4, 3204],
#  [808, 1, 3, 46, 15, 1082],
#  [1077, 1, 1, 58, 13, 3902],
#  [621, 1, 0, 54, 20, 2801],
#  [942, 1, 8, 27, 9, 587],
#  [1092, 1, 8, 45, 10, 1303],
#  [1981, 1, 13, 45, 18, 1380],
#  [1545, 1, 15, 35, 20, 3197],
#  [1744, 0, 1, 20, 3, 1205],
#  [999, 1, 11, 64, 19, 2593],
#  [926, 0, 6, 59, 14, 256],
#  [1840, 1, 12, 34, 16, 1078],
#  [1281, 1, 3, 8, 19, 1851],
#  [1590, 1, 12, 14, 15, 2836],
#  [899, 0, 3, 53, 11, 2870],
#  [1348, 1, 5, 36, 6, 2554],
#  [642, 0, 3, 34, 15, 3355],
#  [1561, 1, 1, 27, 10, 1205],
#  [1934, 1, 0, 46, 17, 2940],
#  [825, 1, 0, 23, 0, 3278],
#  [1425, 0, 0, 33, 2, 3771],
#  [816, 0, 4, 14, 13, 1018],
#  [1425, 0, 9, 35, 14, 590],
#  [1083, 0, 3, 41, 5, 1543],
#  [964, 0, 0, 22, 0, 2577],
#  [956, 0, 1, 41, 6, 3286],
#  [1770, 0, 0, 9, 5, 3785],
#  [609, 0, 3, 26, 4, 1866],
#  [1991, 0, 5, 64, 13, 1733],
#  [1596, 1, 7, 7, 9, 2493],
#  [648, 1, 4, 8, 19, 2991],
#  [1986, 0, 7, 51, 9, 3165],
#  [1896, 1, 8, 7, 13, 3684],
#  [1648, 0, 1, 17, 3, 1184],
#  [1720, 0, 18, 2, 20, 2522],
#  [1876, 1, 3, 56, 4, 3021],
#  [1602, 1, 4, 38, 20, 1037],
#  [574, 0, 1, 30, 3, 1167],
#  [726, 0, 0, 43, 0, 1446],
#  [1331, 0, 0, 16, 7, 1026],
#  [765, 1, 0, 47, 1, 2243],
#  [1369, 1, 3, 28, 18, 3206],
#  [680, 1, 9, 9, 11, 2438],
#  [1699, 1, 1, 59, 3, 3796],
#  [574, 1, 16, 38, 17, 3269],
#  [1755, 0, 0, 24, 2, 3937],
#  [848, 1, 4, 36, 16, 2289],
#  [970, 1, 5, 59, 19, 3675],
#  [1405, 0, 0, 8, 7, 2376],
#  [877, 1, 9, 46, 14, 3260],
#  [1175, 0, 2, 19, 9, 1944],
#  [1068, 1, 0, 45, 1, 1754],
#  [1367, 0, 4, 56, 6, 299],
#  [618, 0, 8, 16, 14, 2262],
#  [1510, 1, 1, 32, 8, 854],
#  [1490, 1, 4, 64, 8, 3600],
#  [1563, 0, 0, 24, 0, 3660],
#  [1940, 1, 0, 5, 1, 820],
#  [1072, 1, 6, 19, 16, 2715],
#  [1600, 1, 1, 19, 9, 1179],
#  [979, 1, 0, 5, 2, 3449],
#  [1289, 1, 3, 16, 17, 3167],
#  [1057, 0, 3, 41, 10, 2033],
#  [1632, 0, 0, 41, 1, 2614],
#  [1550, 0, 2, 32, 5, 1571],
#  [1652, 1, 1, 36, 5, 2338],
#  [1163, 1, 0, 49, 0, 2768],
#  [1970, 1, 11, 58, 19, 2372],
#  [1788, 0, 0, 6, 16, 2321],
#  [641, 0, 0, 7, 3, 3595],
#  [1852, 0, 4, 10, 18, 3970],
#  [1276, 1, 2, 53, 3, 3798],
#  [1949, 1, 2, 31, 9, 832],
#  [1554, 1, 11, 5, 12, 3635],
#  [1579, 1, 0, 5, 9, 3532],
#  [772, 1, 1, 10, 2, 3242],
#  [733, 1, 0, 63, 10, 984],
#  [1727, 0, 2, 63, 8, 2457],
#  [1617, 0, 14, 29, 20, 3685],
#  [967, 0, 4, 25, 9, 3076],
#  [1790, 1, 9, 2, 14, 1366],
#  [1203, 1, 0, 11, 12, 1672],
#  [1836, 1, 0, 14, 1, 2469],
#  [1869, 0, 0, 30, 13, 1375],
#  [1501, 0, 12, 2, 15, 2487],
#  [1278, 0, 10, 60, 14, 3142],
#  [955, 0, 2, 2, 10, 1974],
#  [1369, 1, 6, 34, 7, 3856],
#  [1439, 0, 12, 20, 17, 1790],
#  [729, 0, 0, 14, 2, 3397],
#  [513, 0, 8, 27, 13, 3400],
#  [582, 1, 3, 27, 10, 2437],
#  [1977, 1, 2, 31, 6, 2641],
#  [863, 1, 5, 6, 13, 520],
#  [1552, 0, 10, 53, 18, 2606],
#  [1428, 0, 0, 7, 2, 1808],
#  [1059, 0, 8, 61, 18, 3716],
#  [1546, 1, 3, 6, 4, 3521],
#  [1373, 1, 2, 50, 12, 3800],
#  [1528, 1, 3, 55, 6, 1282],
#  [1946, 1, 8, 8, 19, 3117],
#  [1413, 1, 4, 39, 12, 3878],
#  [1396, 0, 0, 37, 15, 2694],
#  [1523, 0, 6, 11, 8, 707],
#  [1604, 0, 1, 6, 15, 3564],
#  [1494, 0, 3, 45, 4, 3208],
#  [1744, 0, 0, 62, 0, 345],
#  [1976, 1, 4, 32, 7, 3699],
#  [1519, 0, 0, 32, 10, 2912],
#  [1170, 0, 6, 14, 13, 715],
#  [1333, 0, 3, 59, 5, 3442],
#  [697, 1, 5, 20, 6, 259],
#  [1259, 1, 0, 13, 0, 340],
#  [818, 0, 14, 43, 15, 546],
#  [1253, 1, 5, 5, 19, 1878],
#  [1811, 1, 0, 32, 0, 348],
#  [1900, 1, 0, 55, 1, 3917],
#  [793, 1, 1, 38, 7, 3139],
#  [1053, 0, 7, 42, 17, 1339],
#  [1831, 1, 2, 43, 5, 3834],
#  [1371, 0, 4, 52, 19, 3034],
#  [1046, 1, 0, 58, 0, 3863],
#  [618, 1, 2, 57, 7, 2399],
#  [1186, 1, 2, 21, 4, 2361],
#  [1708, 1, 18, 49, 19, 3388],
#  [673, 1, 2, 3, 9, 2719],
#  [1028, 0, 1, 30, 10, 1424],
#  [846, 0, 0, 58, 15, 2248],
#  [506, 0, 6, 41, 7, 2965],
#  [1430, 1, 1, 27, 16, 2832],
#  [1029, 1, 5, 5, 8, 582],
#  [1520, 0, 5, 33, 18, 3826],
#  [913, 1, 1, 41, 14, 2278],
#  [1061, 0, 3, 52, 4, 999],
#  [1142, 0, 0, 2, 0, 1747],
#  [1719, 1, 0, 52, 1, 2610],
#  [1131, 1, 11, 49, 18, 1835],
#  [1640, 1, 1, 36, 11, 3235],
#  [973, 1, 5, 53, 7, 1861],
#  [1624, 1, 8, 28, 10, 2473],
#  [1092, 1, 10, 11, 14, 737],
#  [920, 1, 5, 25, 14, 785],
#  [1695, 1, 1, 34, 10, 3296],
#  [508, 1, 0, 9, 2, 2616],
#  [1775, 0, 3, 41, 7, 2343],
#  [1702, 1, 8, 2, 19, 435],
#  [740, 0, 1, 12, 11, 1105],
#  [820, 1, 2, 58, 4, 1284],
#  [1620, 1, 6, 5, 18, 1086],
#  [1766, 0, 1, 29, 20, 2316],
#  [1589, 1, 0, 58, 7, 3464],
#  [1444, 0, 9, 38, 16, 3764],
#  [1063, 1, 2, 48, 4, 2910],
#  [793, 1, 1, 64, 2, 2296],
#  [752, 1, 1, 48, 13, 3860],
#  [994, 1, 0, 56, 3, 3190],
#  [564, 1, 0, 51, 1, 1074],
#  [1541, 1, 6, 5, 10, 1795],
#  [891, 1, 1, 18, 3, 1303],
#  [1982, 0, 12, 24, 16, 3511],
#  [1422, 0, 15, 3, 17, 509],
#  [553, 1, 1, 8, 3, 1204],
#  [1646, 0, 3, 25, 5, 686],
#  [1160, 0, 1, 63, 2, 595],
#  [516, 1, 1, 30, 12, 3731],
#  [914, 0, 0, 26, 0, 1122],
#  [1866, 0, 0, 30, 0, 3834],
#  [1848, 1, 7, 12, 19, 3915],
#  [823, 0, 0, 39, 4, 294],
#  [1578, 1, 2, 37, 19, 2458],
#  [790, 1, 16, 11, 17, 3169],
#  [1549, 1, 0, 62, 4, 799],
#  [1318, 0, 1, 45, 7, 755],
#  [1641, 0, 6, 48, 7, 1695],
#  [507, 1, 0, 39, 0, 2124],
#  [1343, 1, 5, 14, 10, 462],
#  [1472, 0, 6, 61, 19, 2677],
#  [1063, 0, 0, 31, 10, 961],
#  [825, 1, 7, 52, 10, 3534],
#  [1928, 0, 9, 19, 20, 3777],
#  [721, 1, 6, 6, 9, 530],
#  [1048, 0, 2, 29, 4, 2146],
#  [1511, 1, 3, 21, 18, 3746],
#  [874, 0, 5, 8, 20, 582],
#  [972, 1, 5, 13, 8, 1615],
#  [1589, 0, 9, 46, 16, 2373],
#  [1212, 0, 1, 46, 8, 2249],
#  [1892, 0, 5, 47, 10, 2172],
#  [1108, 1, 14, 2, 20, 1229],
#  [1220, 0, 3, 62, 8, 2589],
#  [771, 0, 3, 25, 6, 770],
#  [826, 0, 3, 62, 19, 1998],
#  [603, 1, 3, 35, 16, 3703],
#  [1510, 1, 2, 45, 3, 3484],
#  [1349, 1, 3, 46, 12, 2367],
#  [956, 1, 1, 42, 11, 3700],
#  [615, 1, 7, 58, 8, 1906],
#  [601, 0, 4, 26, 18, 918],
#  [1907, 0, 13, 55, 15, 286],
#  [1444, 1, 0, 6, 1, 712],
#  [1791, 1, 1, 33, 4, 594],
#  [518, 1, 0, 3, 1, 2832],
#  [1918, 0, 2, 10, 10, 1717],
#  [950, 0, 6, 55, 7, 1305],
#  [612, 0, 6, 35, 12, 3169],
#  [1472, 0, 4, 20, 6, 797],
#  [1310, 1, 13, 7, 14, 3182],
#  [1110, 0, 2, 12, 5, 624],
#  [804, 1, 12, 41, 13, 2027],
#  [1358, 1, 0, 20, 0, 3406],
#  [1117, 0, 1, 12, 8, 2895],
#  [1541, 1, 10, 28, 15, 1108],
#  [1809, 0, 6, 23, 19, 2784],
#  [511, 1, 12, 50, 16, 1484],
#  [1175, 1, 1, 45, 7, 2240],
#  [1796, 0, 4, 44, 11, 3577],
#  [1614, 0, 8, 55, 17, 3914],
#  [1403, 0, 2, 26, 3, 3371],
#  [1709, 0, 1, 13, 2, 3283],
#  [827, 1, 9, 35, 17, 2367],
#  [565, 1, 1, 50, 8, 2156],
#  [1403, 1, 3, 62, 13, 921],
#  [666, 1, 7, 54, 13, 1254],
#  [1703, 0, 0, 22, 0, 1046],
#  [1670, 1, 0, 47, 15, 876],
#  [1450, 1, 9, 19, 17, 575],
#  [1035, 1, 8, 11, 10, 2002],
#  [1074, 1, 2, 9, 14, 1948],
#  [911, 0, 0, 46, 1, 363],
#  [848, 1, 10, 19, 18, 3359],
#  [851, 1, 7, 54, 9, 1005],
#  [571, 0, 1, 43, 8, 2587],
#  [1635, 1, 0, 2, 0, 2315],
#  [551, 0, 0, 54, 15, 1414],
#  [1883, 1, 6, 30, 10, 3724],
#  [899, 1, 13, 57, 18, 364],
#  [1130, 0, 4, 58, 14, 1018],
#  [1452, 1, 1, 25, 11, 2669],
#  [764, 1, 1, 13, 2, 3148],
#  [1300, 0, 5, 62, 7, 874],
#  [999, 0, 6, 49, 17, 1598],
#  [1647, 1, 3, 38, 15, 2532],
#  [1571, 0, 0, 19, 1, 666],
#  [1989, 1, 0, 41, 13, 1665],
#  [1445, 0, 0, 53, 14, 1099],
#  [1874, 1, 10, 8, 13, 1246],
#  [1661, 0, 0, 29, 0, 591],
#  [1702, 0, 7, 36, 9, 1430],
#  [969, 0, 0, 45, 0, 404],
#  [1289, 0, 10, 25, 12, 1043],
#  [1531, 0, 0, 60, 1, 2524],
#  [1581, 0, 9, 41, 19, 1384],
#  [1424, 1, 16, 23, 18, 1053],
#  [1939, 1, 0, 55, 10, 1047],
#  [1826, 1, 5, 49, 6, 1612],
#  [718, 0, 10, 59, 13, 1824],
#  [538, 0, 12, 2, 13, 417],
#  [894, 1, 16, 16, 20, 3377],
#  [835, 1, 2, 42, 18, 2583],
#  [1396, 1, 0, 44, 1, 1386],
#  [1880, 0, 0, 7, 1, 2968],
#  [1960, 0, 1, 7, 9, 3773],
#  [798, 1, 7, 2, 15, 3593],
#  [584, 1, 1, 19, 4, 3996],
#  [920, 0, 2, 46, 3, 2608],
#  [1860, 1, 2, 55, 3, 676],
#  [757, 1, 5, 58, 7, 3237],
#  [840, 1, 5, 15, 8, 2636],
#  [1448, 1, 13, 26, 16, 1175],
#  [1110, 0, 4, 41, 16, 2572],
#  [763, 1, 8, 2, 14, 1050],
#  [708, 0, 0, 26, 1, 1419],
#  [1342, 0, 0, 31, 1, 2746],
#  [665, 0, 0, 31, 2, 690],
#  [1948, 1, 4, 5, 13, 361],
#  [1485, 0, 3, 44, 14, 3271],
#  [1266, 0, 0, 5, 9, 1687],
#  [759, 0, 3, 39, 8, 968],
#  [1698, 0, 10, 26, 18, 1656],
#  [864, 0, 3, 35, 7, 1904],
#  [1183, 1, 3, 48, 12, 1152],
#  [1391, 0, 2, 36, 6, 3139],
#  [1309, 1, 0, 33, 14, 2334],
#  [1806, 1, 2, 54, 11, 3142],
#  [680, 0, 13, 34, 17, 3845],
#  [1122, 0, 0, 40, 14, 1456],
#  [694, 1, 15, 36, 20, 3676],
#  [1421, 0, 0, 57, 2, 2775],
#  [544, 1, 2, 7, 15, 1675],
#  [1920, 1, 3, 19, 8, 3943],
#  [1034, 1, 6, 37, 20, 3625],
#  [1564, 1, 1, 42, 2, 3376],
#  [1084, 0, 3, 40, 11, 1945],
#  [675, 0, 10, 60, 15, 1735],
#  [1602, 1, 0, 35, 7, 1829],
#  [1849, 0, 1, 29, 12, 3330],
#  [741, 0, 1, 14, 13, 1886],
#  [1851, 0, 0, 53, 2, 2678],
#  [674, 1, 1, 21, 4, 1180],
#  [1930, 0, 11, 16, 12, 1783],
#  [1312, 1, 0, 24, 0, 3833],
#  [1438, 0, 3, 16, 7, 2246],
#  [1849, 0, 7, 15, 19, 3447],
#  [805, 0, 0, 64, 14, 418],
#  [560, 1, 6, 57, 12, 2167],
#  [553, 1, 0, 18, 1, 3300],
#  [659, 0, 0, 24, 2, 3925],
#  [1497, 0, 5, 32, 9, 1329],
#  [1271, 1, 0, 2, 1, 892],
#  [917, 0, 1, 31, 2, 3424],
#  [1315, 0, 7, 64, 16, 3278],
#  [1089, 1, 12, 2, 15, 2765],
#  [1861, 0, 4, 55, 8, 601],
#  [1590, 1, 3, 21, 18, 1701],
#  [748, 0, 0, 27, 4, 2126],
#  [875, 1, 1, 43, 3, 3396],
#  [659, 1, 2, 3, 6, 967],
#  [520, 0, 0, 31, 14, 2753],
#  [1558, 0, 2, 32, 3, 878],
#  [1885, 1, 12, 14, 15, 1277],
#  [589, 0, 1, 59, 4, 362],
#  [514, 0, 7, 37, 9, 3392],
#  [733, 0, 5, 7, 10, 1403],
#  [1987, 0, 0, 50, 18, 857],
#  [1772, 1, 3, 64, 15, 1834],
#  [1067, 1, 0, 58, 0, 706],
#  [1891, 0, 7, 37, 14, 3704],
#  [1732, 0, 2, 61, 3, 3940],
#  [503, 1, 5, 8, 13, 2583],
#  [1397, 1, 5, 3, 15, 1378],
#  [1845, 1, 10, 61, 12, 1731],
#  [1407, 0, 1, 22, 4, 2192],
#  [609, 0, 15, 44, 16, 2581],
#  [1358, 0, 11, 36, 14, 3068],
#  [772, 1, 7, 6, 10, 929],
#  [1054, 1, 10, 38, 12, 1675],
#  [1645, 0, 1, 21, 2, 783],
#  [1811, 0, 4, 5, 16, 2700],
#  [1940, 1, 4, 17, 7, 2297],
#  [1830, 0, 0, 7, 12, 2334],
#  [1982, 0, 2, 12, 20, 1824],
#  [706, 0, 13, 31, 19, 2419],
#  [1533, 1, 18, 17, 20, 2520],
#  [1106, 0, 4, 54, 9, 2674],
#  [932, 0, 1, 60, 2, 1459],
#  [1216, 0, 4, 47, 7, 2268],
#  [1454, 0, 8, 6, 20, 1300],
#  [1265, 1, 4, 49, 5, 1518],
#  [983, 0, 0, 53, 4, 1389],
#  [1971, 1, 0, 40, 19, 571],
#  [645, 0, 10, 63, 14, 3615],
#  [664, 0, 5, 6, 19, 3774],
#  [1753, 1, 0, 31, 18, 1324],
#  [1881, 0, 4, 51, 7, 1229],
#  [663, 1, 0, 25, 1, 3176],
#  [1384, 1, 15, 60, 18, 1221],
#  [1872, 1, 14, 49, 18, 3153],
#  [1093, 1, 2, 22, 14, 1869],
#  [712, 1, 3, 35, 10, 2190],
#  [1674, 1, 0, 52, 7, 2030],
#  [539, 1, 9, 21, 14, 3597],
#  [1938, 1, 5, 44, 9, 3497],
#  [1063, 0, 0, 27, 7, 2668],
#  [1926, 0, 13, 50, 17, 3809],
#  [1264, 1, 2, 34, 3, 419],
#  [865, 1, 8, 59, 9, 2361],
#  [1957, 1, 11, 31, 16, 3801],
#  [1925, 1, 0, 16, 11, 2173],
#  [1162, 0, 0, 50, 10, 1404],
#  [1408, 1, 10, 45, 14, 3952],
#  [763, 0, 9, 51, 12, 2865],
#  [1219, 1, 0, 17, 4, 705],
#  [1718, 1, 14, 6, 16, 3755],
#  [1189, 0, 5, 7, 20, 841],
#  [1868, 1, 0, 42, 4, 3131],
#  [1676, 0, 2, 37, 3, 2515],
#  [1260, 0, 5, 13, 6, 2710],
#  [1807, 0, 0, 16, 0, 2921],
#  [1537, 0, 11, 46, 17, 2857],
#  [1076, 1, 0, 14, 0, 2355],
#  [1958, 1, 0, 4, 3, 1409],
#  [727, 1, 0, 64, 9, 3654],
#  [1034, 1, 2, 45, 4, 969],
#  [1793, 1, 11, 27, 13, 1370],
#  [1975, 1, 2, 31, 17, 3022],
#  [612, 1, 1, 20, 6, 3282],
#  [902, 0, 3, 3, 9, 3411],
#  [915, 0, 6, 56, 17, 905],
#  [1144, 1, 0, 21, 11, 3252],
#  [1617, 0, 1, 63, 10, 2754],
#  [553, 1, 2, 23, 3, 2981],
#  [1331, 0, 8, 55, 15, 1732],
#  [754, 1, 7, 59, 10, 1027],
#  [946, 1, 8, 25, 15, 2177],
#  [1995, 0, 6, 26, 15, 1322],
#  [1224, 1, 2, 44, 9, 621],
#  [1577, 1, 0, 64, 7, 2967],
#  [1128, 1, 6, 33, 7, 1440],
#  [972, 0, 8, 44, 10, 3925],
#  [1919, 0, 5, 48, 6, 1391],
#  [957, 0, 4, 7, 10, 1846],
#  [1961, 0, 10, 55, 20, 2355],
#  [501, 1, 14, 22, 20, 3077],
#  [915, 1, 9, 33, 16, 2156],
#  [808, 0, 7, 20, 14, 1471],
#  [748, 0, 0, 25, 14, 1974],
#  [1083, 1, 1, 39, 2, 3248],
#  [1151, 1, 0, 31, 1, 2377],
#  [504, 1, 0, 40, 0, 470],
#  [840, 0, 0, 63, 19, 3486],
#  [1334, 0, 5, 42, 14, 2542],
#  [1837, 1, 5, 12, 6, 2294],
#  [668, 0, 2, 48, 19, 1201],
#  [1989, 1, 8, 17, 15, 2369],
#  [774, 0, 7, 55, 18, 3916],
#  [1136, 0, 0, 9, 2, 2110],
#  [1973, 1, 3, 21, 7, 1724],
#  [808, 0, 3, 45, 9, 3431],
#  [961, 1, 0, 57, 3, 2782],
#  [965, 0, 15, 53, 19, 3227],
#  [1043, 0, 3, 29, 17, 1183],
#  [977, 1, 2, 57, 7, 1206],
#  [1933, 1, 1, 16, 9, 838],
#  [1770, 1, 0, 7, 6, 1480],
#  [1758, 0, 11, 13, 14, 1897],
#  [1313, 1, 4, 9, 6, 3791],
#  [1709, 0, 8, 58, 10, 1781],
#  [599, 0, 0, 64, 1, 3396],
#  [601, 0, 4, 4, 13, 532],
#  [651, 1, 2, 63, 4, 2244],
#  [1099, 0, 13, 61, 20, 1699],
#  [1202, 1, 0, 19, 1, 595],
#  [1441, 1, 0, 53, 12, 1393],
#  [1395, 0, 0, 55, 1, 3373],
#  [1846, 0, 1, 19, 2, 1333],
#  [1504, 0, 12, 34, 15, 2806],
#  [1562, 1, 0, 52, 9, 2829],
#  [993, 1, 0, 16, 13, 1113],
#  [803, 0, 7, 17, 11, 2680],
#  [685, 0, 7, 17, 20, 1223],
#  [1097, 0, 0, 60, 17, 509],
#  [1379, 0, 5, 36, 7, 3426],
#  [946, 0, 9, 26, 10, 1637],
#  [1735, 1, 0, 59, 0, 3230],
#  [1018, 0, 8, 16, 10, 3143],
#  [1512, 0, 4, 46, 5, 869],
#  [616, 1, 13, 44, 17, 3366],
#  [1540, 1, 1, 60, 12, 1591],
#  [1731, 1, 18, 60, 20, 1220],
#  [1314, 1, 8, 41, 12, 626],
#  [554, 0, 0, 12, 10, 3764],
#  [1413, 1, 5, 51, 11, 3383],
#  [1814, 1, 1, 9, 2, 3556],
#  [807, 0, 9, 8, 20, 1284],
#  [1303, 0, 6, 10, 15, 2219],
#  [1662, 0, 0, 61, 13, 3760],
#  [1788, 1, 15, 2, 20, 2655],
#  [1201, 0, 1, 10, 5, 726],
#  [981, 1, 0, 2, 7, 1539],
#  [1959, 1, 5, 18, 20, 619],
#  [1526, 1, 2, 38, 6, 3317],
#  [1361, 0, 1, 47, 2, 2495],
#  [1910, 0, 0, 29, 2, 2944],
#  [507, 1, 1, 32, 11, 1702],
#  [1225, 1, 0, 2, 1, 2675],
#  [1165, 0, 11, 41, 12, 764],
#  [1230, 0, 0, 48, 2, 1622],
#  [987, 1, 0, 61, 9, 3963],
#  [1568, 0, 16, 33, 20, 508],
#  [811, 1, 5, 2, 13, 2111],
#  [1426, 0, 2, 42, 10, 1356],
#  [987, 0, 9, 17, 17, 3885],
#  [1396, 1, 0, 46, 1, 2389],
#  [1965, 0, 6, 4, 9, 3535],
#  [1689, 0, 11, 9, 15, 2637],
#  [948, 0, 14, 22, 20, 3499],
#  [1807, 1, 0, 38, 0, 1069],
#  [633, 0, 0, 49, 1, 3560],
#  [1898, 1, 3, 56, 4, 2114],
#  [685, 1, 8, 13, 15, 3210],
#  [867, 1, 0, 4, 1, 790],
#  [1414, 1, 5, 44, 6, 3490],
#  [1726, 1, 2, 51, 3, 2239],
#  [833, 0, 4, 27, 6, 2150],
#  [1126, 0, 3, 49, 17, 3739],
#  [1281, 1, 0, 28, 6, 1129],
#  [1654, 0, 1, 11, 2, 1070],
#  [879, 0, 11, 14, 15, 349],
#  [856, 1, 14, 19, 19, 650],
#  [1866, 1, 3, 47, 9, 1444],
#  [1279, 0, 5, 7, 6, 1150],
#  [1628, 1, 11, 56, 13, 3358],
#  [825, 1, 0, 34, 17, 2915],
#  [1009, 1, 7, 2, 15, 2286],
#  [1747, 0, 6, 48, 19, 2362],
#  [788, 1, 4, 57, 12, 3969],
#  [592, 1, 1, 52, 10, 1507],
#  [1114, 0, 4, 9, 15, 907],
#  [1983, 1, 3, 43, 10, 2775],
#  [1813, 1, 0, 5, 8, 759],
#  [987, 0, 4, 52, 8, 2757],
#  [1065, 1, 0, 21, 3, 1193],
#  [1081, 1, 13, 49, 17, 325],
#  [1673, 0, 2, 42, 6, 3094],
#  [1027, 0, 2, 64, 7, 3786],
#  [1512, 0, 12, 6, 17, 2335],
#  [1923, 1, 7, 46, 10, 1489],
#  [916, 0, 0, 47, 1, 1659],
#  [1658, 1, 0, 38, 0, 2609],
#  [1550, 0, 6, 21, 11, 2338],
#  [668, 1, 0, 3, 13, 2746],
#  [1889, 0, 5, 31, 10, 3672],
#  [502, 0, 7, 52, 8, 2666],
#  [742, 0, 0, 21, 1, 331],
#  [1678, 1, 11, 7, 14, 574],
#  [909, 1, 7, 47, 9, 1244],
#  [1615, 0, 14, 15, 16, 3488],
#  [1536, 0, 12, 13, 20, 2020],
#  [1503, 0, 10, 43, 14, 2122],
#  [1628, 0, 5, 33, 8, 3361],
#  [947, 0, 1, 51, 15, 2915],
#  [614, 0, 4, 51, 7, 2854],
#  [843, 0, 1, 56, 17, 2341],
#  [862, 1, 3, 23, 15, 278],
#  [1864, 1, 2, 57, 6, 3586],
#  [875, 1, 1, 30, 8, 702],
#  [1487, 0, 5, 42, 7, 2003],
#  [609, 0, 4, 10, 6, 1905],
#  [1824, 0, 4, 19, 5, 2381],
#  [761, 0, 9, 3, 15, 2248],
#  [1190, 1, 9, 47, 10, 624],
#  [691, 1, 4, 33, 8, 424],
#  [596, 0, 8, 46, 18, 2505],
#  [1112, 0, 0, 12, 6, 3302],
#  [1829, 0, 8, 59, 15, 3142],
#  [1537, 0, 4, 43, 5, 3685],
#  [1317, 0, 6, 12, 9, 425],
#  [730, 1, 3, 27, 10, 3623],
#  [842, 0, 1, 7, 2, 2549],
#  [709, 1, 1, 11, 11, 3568],
#  [1082, 1, 11, 2, 20, 2177],
#  [688, 0, 9, 40, 20, 1382],
#  [1972, 1, 0, 37, 1, 2870],
#  [519, 1, 7, 51, 19, 3763],
#  [1547, 1, 2, 14, 19, 2059],
#  [989, 1, 11, 24, 17, 2819],
#  [730, 0, 9, 9, 15, 2787],
#  [1995, 0, 6, 9, 18, 1203],
#  [1348, 0, 18, 52, 20, 955],
#  [1470, 1, 4, 33, 10, 1633],
#  [1417, 0, 2, 56, 4, 590],
#  [1642, 1, 0, 5, 2, 1333],
#  [689, 0, 2, 45, 11, 3585],
#  [1694, 0, 0, 53, 0, 1653],
#  [1149, 0, 4, 30, 5, 3755],
#  [1185, 0, 0, 31, 7, 2447],
#  [1412, 0, 5, 25, 17, 837],
#  [1349, 1, 5, 55, 7, 2462],
#  [652, 1, 9, 17, 11, 1974],
#  [1193, 0, 7, 20, 13, 1958],
#  [745, 1, 5, 35, 10, 2459],
#  [1307, 0, 2, 7, 3, 1412],
#  [710, 0, 6, 32, 9, 1419],
#  [1454, 1, 1, 34, 3, 3419],
#  [962, 1, 3, 17, 20, 3438],
#  [668, 1, 7, 30, 12, 2399],
#  [1147, 1, 11, 28, 13, 2627],
#  [1712, 0, 1, 63, 12, 3652],
#  [1772, 0, 17, 45, 18, 1146],
#  [1811, 0, 3, 22, 8, 2847],
#  [1485, 1, 0, 28, 1, 3241],
#  [1751, 1, 6, 8, 20, 2969],
#  [600, 0, 9, 6, 15, 3495],
#  [1483, 1, 13, 19, 19, 1587],
#  [744, 1, 0, 33, 2, 2700],
#  [1927, 1, 3, 11, 12, 2916],
#  [1844, 1, 1, 51, 3, 1724],
#  [1330, 0, 11, 37, 20, 2166],
#  [798, 1, 6, 21, 12, 1647],
#  [1095, 0, 4, 45, 5, 560],
#  [1286, 0, 10, 16, 18, 424],
#  [989, 0, 4, 17, 19, 3892],
#  [807, 1, 0, 37, 0, 2319],
#  [1936, 1, 13, 34, 14, 1671],
#  [1590, 1, 0, 7, 17, 1201],
#  [1125, 0, 10, 23, 14, 1641],
#  [636, 0, 8, 28, 15, 2927],
#  [1438, 0, 0, 32, 6, 869],
#  [852, 1, 6, 54, 7, 1275],
#  [1670, 0, 14, 62, 20, 3024],
#  [605, 0, 9, 18, 14, 2301],
#  [1880, 0, 4, 18, 5, 3333],
#  [1782, 1, 6, 58, 13, 2405],
#  [584, 0, 0, 19, 0, 465],
#  [1875, 1, 11, 55, 17, 2712],
#  [1180, 0, 5, 50, 20, 1464],
#  [1544, 0, 12, 45, 20, 1300],
#  [1762, 1, 13, 25, 14, 1896],
#  [1086, 0, 0, 24, 19, 3930],
#  [1692, 1, 4, 46, 6, 1394],
#  [1314, 1, 13, 5, 18, 3411],
#  [1052, 0, 1, 6, 16, 552],
#  [914, 0, 1, 60, 4, 3736],
#  [1760, 0, 1, 50, 2, 2549],
#  [1697, 0, 0, 60, 0, 441],
#  [580, 1, 0, 24, 5, 3565],
#  [1924, 0, 3, 63, 10, 3423],
#  [638, 1, 11, 27, 17, 2735],
#  [1954, 1, 8, 7, 9, 3438],
#  [885, 1, 0, 15, 0, 1410],
#  [1681, 0, 2, 11, 13, 1122],
#  [1715, 0, 4, 3, 6, 514],
#  [1398, 1, 8, 26, 12, 3488],
#  [1625, 1, 2, 50, 17, 670],
#  [1335, 0, 3, 60, 4, 3615],
#  [802, 1, 1, 45, 9, 3713],
#  [1231, 1, 2, 7, 7, 3119],
#  [1327, 0, 10, 23, 16, 872],
#  [1719, 0, 0, 12, 7, 462],
#  [1217, 0, 3, 17, 13, 1711],
#  [731, 1, 0, 28, 0, 1774],
#  [1860, 0, 15, 23, 16, 3918],
#  [1456, 1, 7, 7, 12, 1587],
#  [995, 1, 1, 10, 3, 609],
#  [1616, 1, 3, 52, 8, 657],
#  [511, 1, 1, 52, 10, 3865],
#  [1036, 0, 0, 39, 3, 2101],
#  [1296, 1, 3, 11, 4, 2552],
#  [1914, 0, 1, 35, 2, 643],
#  [1566, 1, 0, 20, 0, 659],
#  [586, 1, 10, 8, 14, 3178],
#  [1768, 0, 0, 2, 2, 3256],
#  [713, 1, 4, 53, 17, 1462],
#  [1631, 1, 2, 3, 12, 301],
#  [1655, 1, 6, 4, 12, 673],
#  [1103, 1, 6, 29, 8, 1837],
#  [1031, 1, 2, 11, 9, 2385],
#  [1354, 1, 3, 26, 6, 2090],
#  [1991, 0, 3, 15, 13, 1861],
#  [550, 0, 16, 23, 17, 302],
#  [930, 1, 1, 14, 10, 2457],
#  [717, 1, 4, 10, 5, 688],
#  [1522, 1, 4, 28, 5, 1368],
#  [1753, 0, 4, 40, 11, 1112],
#  [772, 1, 7, 8, 8, 422],
#  [1359, 1, 1, 58, 3, 1076],
#  [1911, 1, 1, 36, 3, 3057],
#  [535, 0, 5, 24, 19, 524],
#  [1323, 1, 10, 28, 12, 1892],
#  [1127, 1, 5, 57, 13, 2048],
#  [1692, 0, 3, 61, 12, 1354],
#  [1589, 0, 3, 26, 16, 3970],
#  [1890, 0, 4, 48, 5, 2392],
#  [1177, 0, 1, 29, 8, 311],
#  [704, 1, 4, 53, 6, 3653],
#  [536, 0, 0, 53, 0, 1211],
#  [594, 0, 1, 27, 2, 708],
#  [906, 1, 7, 18, 11, 3412],
#  [676, 0, 1, 39, 5, 2064],
#  [1498, 0, 3, 8, 4, 3358],
#  [1855, 0, 5, 32, 18, 3933],
#  [630, 0, 9, 14, 13, 1212],
#  [583, 1, 1, 51, 2, 1799],
#  [541, 0, 0, 10, 0, 1019],
#  [1956, 0, 0, 37, 2, 1109],
#  [1949, 0, 0, 20, 4, 1125],
#  [812, 1, 1, 64, 7, 3102],
#  [1007, 1, 5, 21, 12, 1301],
#  [1766, 1, 1, 22, 4, 3297],
#  [1199, 1, 15, 16, 20, 3448],
#  [581, 0, 5, 56, 10, 354],
#  [869, 0, 0, 2, 3, 3249],
#  [1044, 1, 7, 33, 13, 1816],
#  [1479, 1, 0, 24, 0, 3762],
#  [1624, 1, 0, 58, 11, 1251],
#  [560, 1, 15, 50, 20, 2150],
#  [536, 1, 12, 3, 14, 284],
#  [1793, 0, 12, 44, 17, 2803],
#  [1949, 1, 0, 23, 1, 2478],
#  [1456, 1, 5, 49, 20, 3624],
#  [877, 1, 0, 17, 0, 2004],
#  [925, 0, 9, 56, 14, 2466],
#  [1646, 0, 8, 41, 10, 3339],
#  [1447, 1, 2, 9, 16, 568],
#  [1193, 0, 11, 26, 20, 536],
#  [966, 0, 9, 50, 10, 2574],
#  [1988, 0, 0, 16, 1, 3144],
#  [989, 0, 13, 51, 15, 2349],
#  [1464, 1, 0, 17, 8, 1277],
#  [1591, 1, 4, 52, 16, 282],
#  [684, 1, 3, 63, 9, 3756],
#  [753, 0, 11, 48, 20, 3484],
#  [772, 1, 12, 39, 14, 2819],
#  [1672, 1, 13, 32, 20, 1267],
#  [922, 0, 0, 47, 14, 1464],
#  [1322, 1, 6, 7, 9, 1418],
#  [1996, 0, 5, 51, 9, 2236],
#  [657, 0, 0, 37, 1, 1412],
#  [1588, 0, 0, 61, 13, 3272],
#  [672, 1, 13, 61, 20, 1457],
#  [1595, 0, 7, 12, 19, 3608],
#  [709, 1, 0, 35, 0, 1973],
#  [1663, 0, 0, 40, 15, 1336],
#  [1713, 1, 5, 20, 17, 971],
#  [1213, 0, 0, 16, 0, 2700],
#  [602, 0, 9, 50, 18, 2189],
#  [508, 0, 7, 42, 8, 663],
#  [1887, 1, 6, 17, 7, 3348],
#  [1150, 1, 4, 27, 17, 1610],
#  [1444, 0, 2, 48, 17, 2540],
#  [1547, 1, 6, 45, 8, 505],
#  [922, 1, 1, 35, 15, 1165],
#  [1584, 0, 6, 41, 15, 1561],
#  [1063, 0, 7, 3, 10, 1919],
#  [799, 0, 1, 63, 6, 431],
#  [1562, 1, 1, 20, 10, 3465],
#  [854, 0, 5, 17, 9, 3115],
#  [659, 1, 7, 5, 10, 2190],
#  [1899, 0, 0, 26, 0, 336],
#  [894, 0, 2, 58, 3, 3305],
#  [1542, 0, 1, 43, 11, 3601],
#  [1003, 0, 16, 16, 19, 1798],
#  [1699, 0, 16, 21, 20, 1181],
#  [1576, 0, 8, 5, 17, 3904],
#  [1970, 1, 0, 15, 0, 1658],
#  [973, 0, 5, 57, 16, 2977],
#  [838, 0, 1, 13, 4, 3554],
#  [1839, 0, 9, 54, 11, 927],
#  [518, 0, 0, 62, 0, 2514],
#  [1937, 0, 17, 58, 19, 3321],
#  [1983, 1, 6, 27, 11, 3897],
#  [1730, 1, 0, 20, 10, 1595],
#  [1905, 1, 9, 36, 20, 1287],
#  [1812, 1, 4, 42, 15, 3338],
#  [1296, 1, 0, 14, 3, 490],
#  [1660, 0, 2, 15, 8, 2424],
#  [713, 1, 0, 42, 14, 928],
#  [1727, 1, 10, 57, 18, 512],
#  [986, 0, 13, 28, 20, 1149],
#  [1493, 1, 13, 53, 16, 2083],
#  [1808, 1, 1, 31, 16, 2736],
#  [1330, 1, 1, 40, 5, 2678],
#  [1569, 1, 8, 59, 16, 3672],
#  [1811, 0, 0, 33, 2, 2610],
#  [1083, 1, 1, 64, 11, 3210],
#  [1804, 0, 9, 22, 19, 3472],
#  [1129, 1, 0, 49, 2, 1857],
#  [1569, 1, 3, 33, 13, 3538],
#  [1603, 1, 1, 17, 8, 1637],
#  [618, 0, 11, 45, 20, 2339],
#  [1515, 1, 4, 24, 6, 3104],
#  [1263, 0, 12, 64, 18, 1183],
#  [1488, 0, 1, 39, 6, 3054],
#  [1742, 1, 9, 43, 12, 2610],
#  [640, 0, 0, 20, 15, 2844],
#  [777, 0, 3, 30, 17, 3886],
#  [1277, 1, 0, 35, 6, 3559],
#  [1004, 1, 0, 35, 9, 3772],
#  [1517, 0, 6, 48, 14, 2822],
#  [1689, 1, 0, 13, 9, 1172],
#  [1979, 1, 0, 19, 9, 411],
#  [1900, 0, 1, 18, 9, 2871],
#  [614, 1, 0, 58, 2, 3487],
#  [1900, 1, 1, 41, 6, 850],
#  [1248, 0, 6, 9, 8, 2454],
#  [999, 1, 0, 27, 1, 1344],
#  [1429, 0, 8, 42, 9, 1817],
#  [1571, 0, 1, 30, 3, 586],
#  [1843, 0, 1, 62, 7, 3899],
#  [903, 1, 0, 50, 0, 711],
#  [1445, 1, 7, 20, 15, 1441],
#  [1306, 1, 2, 33, 9, 2521],
#  [1104, 0, 1, 60, 13, 1229],
#  [1375, 1, 2, 12, 13, 2890],
#  [1576, 1, 0, 14, 4, 3220],
#  [1273, 0, 3, 48, 15, 1767],
#  [1135, 1, 9, 43, 11, 3204],
#  [1575, 1, 0, 11, 20, 2182],
#  [1449, 1, 3, 10, 12, 1032],
#  [959, 1, 15, 20, 19, 3965],
#  [644, 0, 0, 22, 3, 1262],
#  [955, 1, 4, 43, 8, 1432],
#  [1853, 1, 1, 27, 13, 1973],
#  [912, 1, 6, 46, 11, 851],
#  [1648, 0, 6, 64, 9, 610],
#  [726, 0, 0, 40, 20, 1342],
#  [719, 0, 7, 6, 8, 841],
#  [1261, 1, 0, 11, 0, 348],
#  [1714, 1, 7, 31, 10, 3707],
#  [1097, 0, 10, 21, 15, 2219],
#  [1481, 1, 4, 37, 13, 2945],
#  [1960, 1, 1, 61, 3, 3865],
#  [1166, 0, 3, 25, 4, 2488],
#  [1520, 0, 1, 24, 8, 3233],
#  [1864, 0, 8, 46, 12, 2686],
#  [1642, 1, 16, 8, 17, 2984],
#  [1433, 0, 7, 4, 11, 258],
#  [1234, 1, 8, 17, 15, 3351],
#  [1086, 1, 0, 43, 1, 3285],
#  [1332, 1, 2, 11, 4, 1285],
#  [991, 0, 2, 12, 6, 2014],
#  [1484, 0, 3, 12, 5, 1457],
#  [1876, 0, 10, 40, 14, 2513],
#  [865, 0, 5, 16, 12, 3494],
#  [798, 0, 5, 4, 9, 2965],
#  [904, 1, 10, 31, 11, 2814],
#  [1802, 1, 8, 27, 16, 1885],
#  [644, 1, 7, 30, 16, 2382],
#  [1876, 1, 9, 64, 19, 3132],
#  [787, 0, 15, 11, 16, 2934],
#  [1496, 1, 4, 42, 5, 854],
#  [1359, 0, 4, 59, 6, 3142],
#  [774, 1, 2, 8, 4, 2614],
#  [715, 1, 4, 48, 6, 3709],
#  [1949, 1, 4, 47, 7, 1433],
#  [1967, 0, 0, 46, 7, 1567],
#  [1731, 1, 4, 4, 18, 3892],
#  [1678, 0, 3, 64, 11, 278],
#  [1897, 0, 2, 54, 7, 412],
#  [1143, 1, 1, 22, 6, 1214],
#  [1368, 1, 10, 50, 18, 2496],
#  [1872, 1, 0, 16, 2, 2295],
#  [1395, 1, 0, 23, 1, 2571],
#  [563, 1, 3, 47, 12, 3012],
#  [1416, 1, 0, 20, 0, 3872],
#  [1164, 0, 4, 19, 18, 3309],
#  [1725, 1, 8, 52, 12, 1243],
#  [1000, 0, 12, 63, 18, 3744],
#  [1656, 0, 5, 34, 7, 1629],
#  [969, 1, 2, 44, 7, 641],
#  [1671, 1, 13, 5, 18, 815],
#  [1469, 1, 11, 44, 14, 1687],
#  [622, 1, 12, 11, 14, 3183],
#  [1620, 1, 0, 30, 3, 606],
#  [860, 1, 1, 49, 13, 3869],
#  [525, 1, 5, 51, 11, 1891],
#  [558, 0, 1, 49, 4, 392],
#  [829, 0, 0, 56, 1, 820],
#  [1057, 0, 4, 5, 13, 3705],
#  [1268, 0, 9, 42, 17, 931],
#  [541, 0, 4, 51, 17, 403],
#  [1485, 0, 2, 32, 9, 2147],
#  [793, 1, 0, 43, 2, 1050],
#  [1330, 0, 6, 52, 12, 3269],
#  [701, 0, 7, 15, 11, 1756],
#  [1271, 1, 2, 54, 3, 990],
#  [1661, 1, 5, 23, 10, 2676],
#  [1288, 1, 3, 61, 6, 1882],
#  [1790, 1, 3, 49, 11, 3568],
#  [1138, 0, 12, 44, 17, 3475],
#  [853, 0, 10, 3, 16, 3701],
#  [561, 1, 7, 2, 13, 665],
#  [1110, 0, 1, 42, 2, 456],
#  [928, 1, 11, 56, 13, 666],
#  [1220, 0, 1, 54, 20, 1037],
#  [1148, 1, 0, 58, 20, 3127],
#  [1872, 0, 5, 26, 10, 2273],
#  [1356, 1, 0, 35, 19, 3451],
#  [1337, 0, 13, 31, 20, 2180],
#  [1113, 1, 0, 25, 10, 277],
#  [705, 0, 5, 57, 9, 1509],
#  [1171, 1, 2, 19, 19, 263],
#  [623, 0, 6, 26, 12, 1769],
#  [1577, 1, 0, 42, 4, 2060],
#  [1820, 0, 5, 51, 10, 2481],
#  ...]

# %% [markdown]
# ### feature scaling

# %%
#allows us to put our features into same scale
#essential for ml algo whic calculates distance b/w data if not scaled 
#features with high value range dominates low one eg:knn,Ann,linear,logistic regressions 
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train=sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train

# %%
new=[[1821,0,13,44,14,1411]]

f = pd.DataFrame(new,columns =['battery_power','dual_sim','fc','int_memory','pc','ram'])

Y_train=sc.fit_transform(f)

Y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       1 new=[[1821,0,13,44,14,1411]]
#       3 f = pd.DataFrame(new,columns =['battery_power','dual_sim','fc','int_memory','pc','ram'])
# ----> 5 Y_train=sc.fit_transform(f)
#       7 Y_train
#
# NameError: name 'sc' is not defined

# %% [markdown]
# ### # Exploratory Data Analysis

# %% [markdown]
# ###### battery power

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(df["battery_power"])
plt.show()

# %% [markdown]
# ### Logistic regression

# %%
#our target var x is having 2 var 0,1 that means it is a classification problem so we use different classific algorithms now
from sklearn.linear_model import LogisticRegression
#fitting the data
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#performing prediction
y_pred1 = log.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.5316666666666666

# %%
log.predict(x_test)
# Out:
# array([1, 1, 1, 0, 2, 2, 0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 1, 3, 2, 2, 3, 3,
#        2, 1, 3, 0, 1, 1, 1, 2, 3, 0, 3, 3, 3, 0, 1, 3, 1, 3, 0, 2, 1, 3,
#        2, 3, 1, 1, 1, 3, 0, 0, 1, 2, 3, 2, 0, 0, 2, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 0, 1, 3, 0, 1, 3, 0, 3, 0, 2, 0, 2, 1, 0, 0, 1, 3, 0, 3, 0,
#        1, 0, 0, 3, 3, 3, 3, 3, 2, 2, 1, 2, 3, 2, 3, 2, 3, 1, 0, 0, 0, 2,
#        3, 2, 3, 3, 1, 3, 0, 3, 1, 1, 3, 1, 0, 0, 0, 3, 2, 0, 3, 3, 3, 1,
#        1, 1, 0, 2, 0, 3, 3, 3, 1, 3, 2, 1, 3, 3, 1, 0, 2, 3, 0, 0, 0, 1,
#        3, 1, 1, 3, 3, 0, 0, 3, 3, 3, 3, 3, 1, 3, 0, 3, 0, 1, 0, 3, 3, 0,
#        0, 3, 0, 1, 3, 3, 2, 3, 1, 1, 3, 3, 0, 3, 1, 1, 3, 3, 0, 3, 3, 3,
#        1, 0, 3, 3, 3, 3, 2, 0, 3, 0, 3, 1, 1, 3, 3, 3, 3, 3, 1, 3, 3, 3,
#        1, 2, 1, 3, 1, 2, 3, 0, 1, 2, 0, 2, 3, 3, 3, 3, 3, 0, 1, 3, 0, 3,
#        0, 1, 1, 3, 1, 3, 1, 3, 3, 3, 3, 1, 1, 2, 0, 2, 3, 0, 1, 1, 3, 0,
#        1, 2, 3, 2, 3, 3, 1, 3, 0, 1, 3, 3, 0, 0, 2, 0, 3, 3, 1, 3, 3, 0,
#        0, 2, 1, 0, 3, 1, 3, 2, 3, 1, 1, 2, 1, 3, 0, 2, 3, 2, 0, 3, 3, 3,
#        0, 2, 3, 1, 1, 0, 0, 1, 0, 3, 3, 0, 3, 3, 3, 3, 2, 0, 3, 2, 3, 3,
#        3, 2, 0, 3, 1, 3, 0, 0, 2, 0, 0, 1, 3, 3, 0, 0, 0, 0, 3, 0, 3, 0,
#        3, 3, 0, 3, 0, 2, 3, 2, 0, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 0, 3, 1,
#        2, 0, 1, 3, 2, 0, 1, 2, 0, 3, 3, 1, 2, 0, 1, 3, 1, 3, 3, 3, 3, 2,
#        0, 0, 3, 0, 1, 1, 1, 3, 3, 3, 3, 3, 0, 1, 1, 3, 1, 3, 2, 1, 1, 0,
#        3, 0, 3, 0, 2, 3, 3, 2, 2, 1, 1, 1, 1, 1, 0, 1, 1, 1, 2, 1, 0, 2,
#        3, 3, 3, 2, 3, 2, 3, 3, 0, 1, 0, 1, 3, 3, 0, 3, 1, 3, 0, 3, 0, 3,
#        1, 0, 0, 1, 2, 2, 3, 3, 3, 2, 2, 0, 0, 1, 2, 1, 1, 2, 1, 3, 2, 3,
#        2, 3, 3, 0, 3, 3, 2, 2, 3, 2, 2, 0, 1, 2, 3, 3, 1, 1, 0, 3, 0, 2,
#        1, 3, 3, 2, 0, 3, 2, 1, 3, 3, 3, 2, 3, 0, 2, 3, 3, 0, 3, 3, 3, 1,
#        2, 1, 3, 3, 0, 3, 0, 1, 3, 3, 2, 3, 3, 0, 3, 3, 3, 3, 3, 3, 1, 1,
#        1, 3, 3, 3, 3, 2, 2, 1, 1, 1, 3, 0, 0, 1, 1, 1, 3, 0, 3, 0, 0, 3,
#        2, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 1, 1, 0, 2, 0, 0, 3, 0,
#        0, 1, 1, 0, 0, 1], dtype=int64)

# %%
x_train
# Out:
#       battery_power  dual_sim  fc  int_memory  pc   ram
# 447            1349         1  15          62  16  2756
# 1254           1083         0   6          52  20   681
# 1492           1130         1   1          29  14   432
# 1399            672         0   7          35  17  1403
# 70             1448         1   6          45  11  3378
# ...             ...       ...  ..         ...  ..   ...
# 347             667         0   6           3  13  2855
# 1476           1638         0   6           2  11  2299
# 1361           1549         1   0          27   7   436
# 563            1290         0   0           3   4  1214
# 1536           1412         0   9          57  10  1853
#
# [1400 rows x 6 columns]

# %% [markdown]
# ### SVC (support vector classificaton)

# %%
from sklearn import svm
svm = svm.SVC()
svm.fit(x_train,y_train)
y_pred2 = svm.predict(x_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.8366666666666667

# %%
log.predict(x_test)
# Out:
# array([1, 1, 1, 0, 2, 2, 0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 1, 3, 2, 2, 3, 3,
#        2, 1, 3, 0, 1, 1, 1, 2, 3, 0, 3, 3, 3, 0, 1, 3, 1, 3, 0, 2, 1, 3,
#        2, 3, 1, 1, 1, 3, 0, 0, 1, 2, 3, 2, 0, 0, 2, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 0, 1, 3, 0, 1, 3, 0, 3, 0, 2, 0, 2, 1, 0, 0, 1, 3, 0, 3, 0,
#        1, 0, 0, 3, 3, 3, 3, 3, 2, 2, 1, 2, 3, 2, 3, 2, 3, 1, 0, 0, 0, 2,
#        3, 2, 3, 3, 1, 3, 0, 3, 1, 1, 3, 1, 0, 0, 0, 3, 2, 0, 3, 3, 3, 1,
#        1, 1, 0, 2, 0, 3, 3, 3, 1, 3, 2, 1, 3, 3, 1, 0, 2, 3, 0, 0, 0, 1,
#        3, 1, 1, 3, 3, 0, 0, 3, 3, 3, 3, 3, 1, 3, 0, 3, 0, 1, 0, 3, 3, 0,
#        0, 3, 0, 1, 3, 3, 2, 3, 1, 1, 3, 3, 0, 3, 1, 1, 3, 3, 0, 3, 3, 3,
#        1, 0, 3, 3, 3, 3, 2, 0, 3, 0, 3, 1, 1, 3, 3, 3, 3, 3, 1, 3, 3, 3,
#        1, 2, 1, 3, 1, 2, 3, 0, 1, 2, 0, 2, 3, 3, 3, 3, 3, 0, 1, 3, 0, 3,
#        0, 1, 1, 3, 1, 3, 1, 3, 3, 3, 3, 1, 1, 2, 0, 2, 3, 0, 1, 1, 3, 0,
#        1, 2, 3, 2, 3, 3, 1, 3, 0, 1, 3, 3, 0, 0, 2, 0, 3, 3, 1, 3, 3, 0,
#        0, 2, 1, 0, 3, 1, 3, 2, 3, 1, 1, 2, 1, 3, 0, 2, 3, 2, 0, 3, 3, 3,
#        0, 2, 3, 1, 1, 0, 0, 1, 0, 3, 3, 0, 3, 3, 3, 3, 2, 0, 3, 2, 3, 3,
#        3, 2, 0, 3, 1, 3, 0, 0, 2, 0, 0, 1, 3, 3, 0, 0, 0, 0, 3, 0, 3, 0,
#        3, 3, 0, 3, 0, 2, 3, 2, 0, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 0, 3, 1,
#        2, 0, 1, 3, 2, 0, 1, 2, 0, 3, 3, 1, 2, 0, 1, 3, 1, 3, 3, 3, 3, 2,
#        0, 0, 3, 0, 1, 1, 1, 3, 3, 3, 3, 3, 0, 1, 1, 3, 1, 3, 2, 1, 1, 0,
#        3, 0, 3, 0, 2, 3, 3, 2, 2, 1, 1, 1, 1, 1, 0, 1, 1, 1, 2, 1, 0, 2,
#        3, 3, 3, 2, 3, 2, 3, 3, 0, 1, 0, 1, 3, 3, 0, 3, 1, 3, 0, 3, 0, 3,
#        1, 0, 0, 1, 2, 2, 3, 3, 3, 2, 2, 0, 0, 1, 2, 1, 1, 2, 1, 3, 2, 3,
#        2, 3, 3, 0, 3, 3, 2, 2, 3, 2, 2, 0, 1, 2, 3, 3, 1, 1, 0, 3, 0, 2,
#        1, 3, 3, 2, 0, 3, 2, 1, 3, 3, 3, 2, 3, 0, 2, 3, 3, 0, 3, 3, 3, 1,
#        2, 1, 3, 3, 0, 3, 0, 1, 3, 3, 2, 3, 3, 0, 3, 3, 3, 3, 3, 3, 1, 1,
#        1, 3, 3, 3, 3, 2, 2, 1, 1, 1, 3, 0, 0, 1, 1, 1, 3, 0, 3, 0, 0, 3,
#        2, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 1, 1, 0, 2, 0, 0, 3, 0,
#        0, 1, 1, 0, 0, 1], dtype=int64)

# %% [markdown]
# ### kNeighbours classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
skfold = StratifiedKFold(n_splits=3)
model_c = KNeighborsClassifier(n_neighbors=10)
results_skfold = model_selection.cross_val_score(model_c, x, y.ravel(), cv=skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# Accuracy: 81.20%

# %% [markdown]
# ### Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(x_test)
accuracy_score(y_test,y_pred4)
# Out:
# 0.7566666666666667

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5 = rf.predict(x_test)
accuracy_score(y_test,y_pred5)
# Out:
# 0.8166666666666667

# %%
final_data=pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF'],
                        'ACC':[accuracy_score(y_test,y_pred1),
                              accuracy_score(y_test,y_pred2),
                              results_skfold.mean(),
                              accuracy_score(y_test,y_pred4),
                              accuracy_score(y_test,y_pred5)]})
final_data
# Out:
#   Models       ACC
# 0     LR  0.531667
# 1    SVC  0.836667
# 2    KNN  0.812005
# 3     DT  0.756667
# 4     RF  0.816667

# %%
import seaborn as sns
sns.barplot(x=final_data['Models'],y=final_data['ACC'])
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# ### Save the model

# %%
x=sc.fit_transform(x)
svm.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 x=sc.fit_transform(x)
#       2 svm.fit(x,y)
#
# NameError: name 'sc' is not defined

# %%
import joblib
joblib.dump(log,'mobile_model')
# Out:
# ['mobile_model']

# %%
model = joblib.load('mobile_model')

# %%
df.columns
# Out:
# Index(['battery_power', 'dual_sim', 'fc', 'int_memory', 'pc', 'ram',
#        'price_range'],
#       dtype='object')

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, 0, 2, 2, 0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 1, 3, 2, 2, 3, 3,
#        2, 1, 3, 0, 1, 1, 1, 2, 3, 0, 3, 3, 3, 0, 1, 3, 1, 3, 0, 2, 1, 3,
#        2, 3, 1, 1, 1, 3, 0, 0, 1, 2, 3, 2, 0, 0, 2, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 0, 1, 3, 0, 1, 3, 0, 3, 0, 2, 0, 2, 1, 0, 0, 1, 3, 0, 3, 0,
#        1, 0, 0, 3, 3, 3, 3, 3, 2, 2, 1, 2, 3, 2, 3, 2, 3, 1, 0, 0, 0, 2,
#        3, 2, 3, 3, 1, 3, 0, 3, 1, 1, 3, 1, 0, 0, 0, 3, 2, 0, 3, 3, 3, 1,
#        1, 1, 0, 2, 0, 3, 3, 3, 1, 3, 2, 1, 3, 3, 1, 0, 2, 3, 0, 0, 0, 1,
#        3, 1, 1, 3, 3, 0, 0, 3, 3, 3, 3, 3, 1, 3, 0, 3, 0, 1, 0, 3, 3, 0,
#        0, 3, 0, 1, 3, 3, 2, 3, 1, 1, 3, 3, 0, 3, 1, 1, 3, 3, 0, 3, 3, 3,
#        1, 0, 3, 3, 3, 3, 2, 0, 3, 0, 3, 1, 1, 3, 3, 3, 3, 3, 1, 3, 3, 3,
#        1, 2, 1, 3, 1, 2, 3, 0, 1, 2, 0, 2, 3, 3, 3, 3, 3, 0, 1, 3, 0, 3,
#        0, 1, 1, 3, 1, 3, 1, 3, 3, 3, 3, 1, 1, 2, 0, 2, 3, 0, 1, 1, 3, 0,
#        1, 2, 3, 2, 3, 3, 1, 3, 0, 1, 3, 3, 0, 0, 2, 0, 3, 3, 1, 3, 3, 0,
#        0, 2, 1, 0, 3, 1, 3, 2, 3, 1, 1, 2, 1, 3, 0, 2, 3, 2, 0, 3, 3, 3,
#        0, 2, 3, 1, 1, 0, 0, 1, 0, 3, 3, 0, 3, 3, 3, 3, 2, 0, 3, 2, 3, 3,
#        3, 2, 0, 3, 1, 3, 0, 0, 2, 0, 0, 1, 3, 3, 0, 0, 0, 0, 3, 0, 3, 0,
#        3, 3, 0, 3, 0, 2, 3, 2, 0, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 0, 3, 1,
#        2, 0, 1, 3, 2, 0, 1, 2, 0, 3, 3, 1, 2, 0, 1, 3, 1, 3, 3, 3, 3, 2,
#        0, 0, 3, 0, 1, 1, 1, 3, 3, 3, 3, 3, 0, 1, 1, 3, 1, 3, 2, 1, 1, 0,
#        3, 0, 3, 0, 2, 3, 3, 2, 2, 1, 1, 1, 1, 1, 0, 1, 1, 1, 2, 1, 0, 2,
#        3, 3, 3, 2, 3, 2, 3, 3, 0, 1, 0, 1, 3, 3, 0, 3, 1, 3, 0, 3, 0, 3,
#        1, 0, 0, 1, 2, 2, 3, 3, 3, 2, 2, 0, 0, 1, 2, 1, 1, 2, 1, 3, 2, 3,
#        2, 3, 3, 0, 3, 3, 2, 2, 3, 2, 2, 0, 1, 2, 3, 3, 1, 1, 0, 3, 0, 2,
#        1, 3, 3, 2, 0, 3, 2, 1, 3, 3, 3, 2, 3, 0, 2, 3, 3, 0, 3, 3, 3, 1,
#        2, 1, 3, 3, 0, 3, 0, 1, 3, 3, 2, 3, 3, 0, 3, 3, 3, 3, 3, 3, 1, 1,
#        1, 3, 3, 3, 3, 2, 2, 1, 1, 1, 3, 0, 0, 1, 1, 1, 3, 0, 3, 0, 0, 3,
#        2, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 1, 1, 0, 2, 0, 0, 3, 0,
#        0, 1, 1, 0, 0, 1], dtype=int64)

# %%
model.predict(Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 model.predict(Y_train)
#
# NameError: name 'Y_train' is not defined

# %% [markdown]
# ### GUI

# %%
import tkinter as tk
from tkinter import *
from sklearn.preprocessing import StandardScaler
import joblib
from PIL import ImageTk,Image

# %%
def show_entry_fields():
    p1=int(e1.get())
    p2=int(e2.get())
    p3=int(e3.get())
    p4=int(e4.get())
    p5=int(e5.get())
    p6=int(e6.get())
    #model = joblib.load('mobile_model')
    new=[[p1,p2,p3,p4,p5,p6]]
    result=svm.predict(new)
    print(result)
    
    if result == 0:
        Label(master, text="5k-10k").grid(row=81)
    elif result == 1:
        Label(master, text="10k-20k").grid(row=81)
    elif result == 2:
        Label(master, text="20k-30k").grid(row=81)
    elif result == 3:
        Label(master, text="30k and above").grid(row=81)
    #else:
        #Label(master, text="invalid").grid(row=81)
master = Tk()
master.title("Mobile price Prediction Using Machine Learning")
master.geometry("700x500")
def on_resize(event):
    image=bg.resize((event.width,event.height),Image.LANCZOS )
    l.image=ImageTk.PhotoImage(image)
    l.config(image=l.image)
bg=Image.open("mobile2.jpg")
l=tk.Label(master)
l.place(x=0,y=0,relwidth=1,relheight=1)
l.bind('<Configure>',on_resize)
label = Label(master, text = "Mobile Price Range Prediction",
  font=("Arial",28,"bold"), bg = "black", fg = "white"). \
                           grid(row=0,columnspan=7)    


Label(master, text="        Battery power              ").grid(row=1,column=2)
Label(master, text="    dual sim(yes=1/no=0)    ").grid(row=2,column=2)
Label(master, text="        Front_Camera               ").grid(row=3,column=2)
Label(master, text="          Memory                       ").grid(row=4,column=2)
Label(master, text="                Processor_core                      ").grid(row=5,column=2)
Label(master, text="               RAM       ").grid(row=6,column=2)

e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)




e1.grid(row=1, column=6)
e2.grid(row=2, column=6)
e3.grid(row=3, column=6)
e4.grid(row=4, column=6)
e5.grid(row=5, column=6)
e6.grid(row=6, column=6)

master.rowconfigure(12,weight=1)
Button(master, text='Predict', command=show_entry_fields,bg = "black", fg = "yellow",borderwidth=3).grid(row=12,column=5)
master.mainloop()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# [3]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# [3]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# [2]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# [1]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# [0]
